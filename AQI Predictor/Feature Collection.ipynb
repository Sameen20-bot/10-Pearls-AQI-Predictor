# %% [markdown]
# # Weather Data Collection From Open Meteo

# %%
import requests
import pandas as pd

# %%
url = "https://archive-api.open-meteo.com/v1/archive"

params = {
	"latitude": 24.8608,
	"longitude": 67.0104,
	"start_date": "2023-08-01",
	"end_date": "2026-08-01",
	"hourly": ["temperature_2m", "wind_speed_10m", "relative_humidity_2m", "surface_pressure"],
	"timezone": "auto",
}

response = requests.get(url, params)

# %%
data = response.json()

# %%
weatherData = pd.DataFrame(data["hourly"])

# %%
weatherData.head()
# Out:
#                time  temperature_2m  wind_speed_10m  relative_humidity_2m  \
# 0  2023-08-01T00:00            27.5            22.2                    90
# 1  2023-08-01T01:00            27.5            22.2                    90
# 2  2023-08-01T02:00            27.4            20.8                    91
# 3  2023-08-01T03:00            27.5            19.2                    91
# 4  2023-08-01T04:00            27.2            19.1                    92
#
#    surface_pressure
# 0            1000.4
# 1             999.9
# 2             999.4
# 3             999.4
# 4             999.3

# %%
weatherData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26328 entries, 0 to 26327
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   time                  26328 non-null  object
#  1   temperature_2m        26328 non-null  float64
#  2   wind_speed_10m        26328 non-null  float64
#  3   relative_humidity_2m  26328 non-null  int64
#  4   surface_pressure      26328 non-null  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.0+ MB

# %%
weatherData.time = pd.to_datetime(weatherData.time)

# %%
weatherData.time = weatherData.time.dt.tz_localize('Asia/Karachi')

# %%
weatherData.head()
# Out:
#                        time  temperature_2m  wind_speed_10m  \
# 0 2023-08-01 00:00:00+05:00            27.5            22.2
# 1 2023-08-01 01:00:00+05:00            27.5            22.2
# 2 2023-08-01 02:00:00+05:00            27.4            20.8
# 3 2023-08-01 03:00:00+05:00            27.5            19.2
# 4 2023-08-01 04:00:00+05:00            27.2            19.1
#
#    relative_humidity_2m  surface_pressure
# 0                    90            1000.4
# 1                    90             999.9
# 2                    91             999.4
# 3                    91             999.4
# 4                    92             999.3

# %%
weatherData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26328 entries, 0 to 26327
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   time                  26328 non-null  datetime64[ns, Asia/Karachi]
#  1   temperature_2m        26328 non-null  float64
#  2   wind_speed_10m        26328 non-null  float64
#  3   relative_humidity_2m  26328 non-null  int64
#  4   surface_pressure      26328 non-null  float64
# dtypes: datetime64[ns, Asia/Karachi](1), float64(3), int64(1)
# memory usage: 1.0 MB

# %% [markdown]
# # AQI Data Collection from Open Meteo

# %%
url2 = "https://air-quality-api.open-meteo.com/v1/air-quality"

params2 = {
	"latitude": 24.8608,
	"longitude": 67.0104,
	"hourly": ["pm10", "pm2_5", "carbon_monoxide", "nitrogen_dioxide", "sulphur_dioxide", "ozone", "us_aqi"],
	"timezone": "auto",
	"start_date": "2023-08-01",
	"end_date": "2026-08-01",
}

response2 = requests.get(url2, params2)

# %%
data2 = response2.json()

# %%
aqiData = pd.DataFrame(data2["hourly"])

# %%
aqiData.head()
# Out:
#                time  pm10  pm2_5  carbon_monoxide  nitrogen_dioxide  \
# 0  2023-08-01T00:00  61.9   20.8            174.0              12.3
# 1  2023-08-01T01:00  62.4   19.7            150.0               9.5
# 2  2023-08-01T02:00  67.1   19.6            131.0               7.3
# 3  2023-08-01T03:00  72.6   19.8            117.0               5.9
# 4  2023-08-01T04:00  75.2   20.4            107.0               5.2
#
#    sulphur_dioxide  ozone  us_aqi
# 0              3.9   33.0      73
# 1              3.6   35.0      73
# 2              3.3   37.0      73
# 3              3.2   38.0      73
# 4              3.2   39.0      73

# %%
aqiData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26328 entries, 0 to 26327
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   time              26328 non-null  object
#  1   pm10              26328 non-null  float64
#  2   pm2_5             26328 non-null  float64
#  3   carbon_monoxide   26328 non-null  float64
#  4   nitrogen_dioxide  26328 non-null  float64
#  5   sulphur_dioxide   26328 non-null  float64
#  6   ozone             26328 non-null  float64
#  7   us_aqi            26328 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 1.6+ MB

# %%
aqiData.time = pd.to_datetime(aqiData.time)

# %%
aqiData.time = aqiData.time.dt.tz_localize('Asia/Karachi')

# %%
aqiData.head()
# Out:
#                        time  pm10  pm2_5  carbon_monoxide  nitrogen_dioxide  \
# 0 2023-08-01 00:00:00+05:00  61.9   20.8            174.0              12.3
# 1 2023-08-01 01:00:00+05:00  62.4   19.7            150.0               9.5
# 2 2023-08-01 02:00:00+05:00  67.1   19.6            131.0               7.3
# 3 2023-08-01 03:00:00+05:00  72.6   19.8            117.0               5.9
# 4 2023-08-01 04:00:00+05:00  75.2   20.4            107.0               5.2
#
#    sulphur_dioxide  ozone  us_aqi
# 0              3.9   33.0      73
# 1              3.6   35.0      73
# 2              3.3   37.0      73
# 3              3.2   38.0      73
# 4              3.2   39.0      73

# %%
aqiData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26328 entries, 0 to 26327
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   time              26328 non-null  datetime64[ns, Asia/Karachi]
#  1   pm10              26328 non-null  float64
#  2   pm2_5             26328 non-null  float64
#  3   carbon_monoxide   26328 non-null  float64
#  4   nitrogen_dioxide  26328 non-null  float64
#  5   sulphur_dioxide   26328 non-null  float64
#  6   ozone             26328 non-null  float64
#  7   us_aqi            26328 non-null  int64
# dtypes: datetime64[ns, Asia/Karachi](1), float64(6), int64(1)
# memory usage: 1.6 MB

# %%
print(aqiData["time"].min())
print(aqiData["time"].max())
print(len(aqiData))
# Out:
# 2023-08-01 00:00:00+05:00
# 2026-08-01 23:00:00+05:00
# 26328

# %% [markdown]
# # Merge The Weather And AQI Data

# %%
AqiData = pd.merge(weatherData, aqiData, on = 'time')

# %%
AqiData.head()
# Out:
#                        time  temperature_2m  wind_speed_10m  \
# 0 2023-08-01 00:00:00+05:00            27.5            22.2
# 1 2023-08-01 01:00:00+05:00            27.5            22.2
# 2 2023-08-01 02:00:00+05:00            27.4            20.8
# 3 2023-08-01 03:00:00+05:00            27.5            19.2
# 4 2023-08-01 04:00:00+05:00            27.2            19.1
#
#    relative_humidity_2m  surface_pressure  pm10  pm2_5  carbon_monoxide  \
# 0                    90            1000.4  61.9   20.8            174.0
# 1                    90             999.9  62.4   19.7            150.0
# 2                    91             999.4  67.1   19.6            131.0
# 3                    91             999.4  72.6   19.8            117.0
# 4                    92             999.3  75.2   20.4            107.0
#
#    nitrogen_dioxide  sulphur_dioxide  ozone  us_aqi
# 0              12.3              3.9   33.0      73
# 1               9.5              3.6   35.0      73
# 2               7.3              3.3   37.0      73
# 3               5.9              3.2   38.0      73
# 4               5.2              3.2   39.0      73

# %%
AqiData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26328 entries, 0 to 26327
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   time                  26328 non-null  datetime64[ns, Asia/Karachi]
#  1   temperature_2m        26328 non-null  float64
#  2   wind_speed_10m        26328 non-null  float64
#  3   relative_humidity_2m  26328 non-null  int64
#  4   surface_pressure      26328 non-null  float64
#  5   pm10                  26328 non-null  float64
#  6   pm2_5                 26328 non-null  float64
#  7   carbon_monoxide       26328 non-null  float64
#  8   nitrogen_dioxide      26328 non-null  float64
#  9   sulphur_dioxide       26328 non-null  float64
#  10  ozone                 26328 non-null  float64
#  11  us_aqi                26328 non-null  int64
# dtypes: datetime64[ns, Asia/Karachi](1), float64(9), int64(2)
# memory usage: 2.4 MB

# %%
AqiData.to_csv("AqiDataKarachi.csv")
