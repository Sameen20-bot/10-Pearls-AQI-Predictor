# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from sklearn.model_selection import RandomizedSearchCV, TimeSeriesSplit

from xgboost import XGBRegressor

# %%
from pathlib import Path

CWD = Path.cwd()
PROJECT_ROOT = CWD.parent.parent
PROCESSED_DIR = PROJECT_ROOT / "Data" / "Processed"

print(PROCESSED_DIR)
# Out:
# C:\Users\Sameen\10 Pearls Project\AQI Predictor\Data\Processed

# %%
df = pd.read_csv(PROCESSED_DIR / "Aqi_Data_Two_Day_Prediction_New.csv", index_col="time", parse_dates=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26208 entries, 2023-08-04 00:00:00+05:00 to 2026-07-30 23:00:00+05:00
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   temperature_2m             26208 non-null  float64
#  1   wind_speed_10m             26208 non-null  float64
#  2   relative_humidity_2m       26208 non-null  int64
#  3   surface_pressure           26208 non-null  float64
#  4   boundary_layer_height      21840 non-null  float64
#  5   dew_point_2m               26208 non-null  float64
#  6   precipitation              26208 non-null  float64
#  7   cloud_cover                26208 non-null  int64
#  8   wind_direction_10m         26208 non-null  int64
#  9   wind_gusts_10m             26208 non-null  float64
#  10  shortwave_radiation        26208 non-null  float64
#  11  pm10                       26208 non-null  float64
#  12  pm2_5                      26208 non-null  float64
#  13  carbon_monoxide            26208 non-null  float64
#  14  nitrogen_dioxide           26208 non-null  float64
#  15  sulphur_dioxide            26208 non-null  float64
#  16  ozone                      26208 non-null  float64
#  17  dust                       26208 non-null  float64
#  18  aerosol_optical_depth      26208 non-null  float64
#  19  us_aqi                     26208 non-null  int64
#  20  hour                       26208 non-null  int64
#  21  day                        26208 non-null  int64
#  22  month                      26208 non-null  int64
#  23  dayofweek                  26208 non-null  int64
#  24  quarter                    26208 non-null  int64
#  25  previous_hour_aqi          26208 non-null  float64
#  26  previous_day_aqi           26208 non-null  float64
#  27  aqi_change_rate            26208 non-null  float64
#  28  rolled_mean_aqi_6hr        26208 non-null  float64
#  29  rolled_mean_aqi_24hr       26208 non-null  float64
#  30  rolled_mean_aqi_72hr       26208 non-null  float64
#  31  rolled_std_aqi_6hr         26208 non-null  float64
#  32  rolled_std_aqi_24hr        26208 non-null  float64
#  33  rolled_std_aqi_72hr        26208 non-null  float64
#  34  ewm_aqi_24hr               26208 non-null  float64
#  35  ewm_std_24hr               26208 non-null  float64
#  36  Day_2_Future_AQI           26208 non-null  float64
#  37  f48_temperature_2m         26208 non-null  float64
#  38  f48_wind_speed_10m         26208 non-null  float64
#  39  f48_relative_humidity_2m   26208 non-null  float64
#  40  f48_surface_pressure       26208 non-null  float64
#  41  f48_boundary_layer_height  21840 non-null  float64
#  42  f48_dew_point_2m           26208 non-null  float64
#  43  f48_precipitation          26208 non-null  float64
#  44  f48_cloud_cover            26208 non-null  float64
#  45  f48_wind_gusts_10m         26208 non-null  float64
#  46  f48_shortwave_radiation    26208 non-null  float64
#  47  wind_pollution_dispersion  21840 non-null  float64
#  48  pressure_change_3hour      26208 non-null  float64
#  49  Humidity_Level             26208 non-null  float64
# dtypes: float64(41), int64(9)
# memory usage: 10.2 MB

# %%
df.head()
# Out:
#                            temperature_2m  wind_speed_10m  \
# time
# 2023-08-04 00:00:00+05:
#        'precipitation', 'cloud_cover', 'wind_direction_10m', 'wind_gusts_10m',
#        'shortwave_radiation', 'pm10', 'pm2_5', 'carbon_monoxide',
#        'nitrogen_dioxide', 'sulphur_dioxide', 'ozone', 'dust',
#        'aerosol_optical_depth', 'us_aqi', 'hour', 'day', 'month', 'dayofweek',
#        'quarter', 'previous_hour_aqi', 'previous_day_aqi', 'aqi_change_rate',
#        'rolled_mean_aqi_6hr', 'rolled_mean_aqi_24hr', 'rolled_mean_aqi_72hr',
#        'rolled_std_aqi_6hr', 'rolled_std_aqi_24hr', 'rolled_std_aqi_72hr',
#        'ewm_aqi_24hr', 'ewm_std_24hr', 'Day_2_Future_AQI',
#        'f48_temperature_2m', 'f48_wind_speed_10m', 'f48_relative_humidity_2m',
#        'f48_surface_pressure', 'f48_boundary_layer_height', 'f48_dew_point_2m',
#        'f48_precipitation', 'f48_cloud_cover', 'f48_wind_gusts_10m',
#        'f48_shortwave_radiation', 'wind_pollution_dispersion',
#        'pressure_change_3hour', 'Humidity_Level'],
#       dtype='object')

# %%
X = df.drop(columns = ['Day_2_Future_AQI'])
Y = df['Day_2_Future_AQI']

# %%
X
# Out:
#                            temperature_2m  wind_speed_10m  \
# time
# 2023-08-04 00:00:00+05:00            27.4            18.7
# 2023-08-04 01:00:00+05:00            27.2            19.0
# 2023-08-04 02:00:00+05:00            27.0            17.7
# 2023-08-04 03:00:00+05:00            26.9            17.1
# 2023-08-04 04:00:00+05:00            27.0            20.0
# ...                                   ...             ...
# 2026-07-30 19:00:00+05:00            29.7            10.7
# 2026-07-30 20:00:00+05:00            29.2             9.6
# 2026-07-30 21:00:00+05:00            29.1             8.3
# 2026-07-30 22:00:00+05:00            29.2             9.0
# 2026-07-30 23:00:00+05:00            29.4             8.5
#
#                            relative_humidity_2m  surface_pressure  \
# time
# 2023-08-04 00:00:00+05:00                    90            1000.1
# 2023-08-04 01:00:00+05:00                    90             999.3
# 2023-08-04 02:00:00+05:00                    92             998.6
# 2023-08-04 03:00:00+05:00                    92             998.7
# 2023-08-04 04:00:00+05:00                    92             998.8
# ...                                         ...               ...
# 2026-07-30 19:00:00+05:00                    81             995.5
# 2026-07-30 20:00:00+05:00                    84             996.0
# 2026-07-30 21:00:00+05:00                    84             996.5
# 2026-07-30 22:00:00+05:00                    83             997.4
# 2026-07-30 23:00:00+05:00                    84             997.5
#
#                            boundary_layer_height  dew_point_2m  precipitation  \
# time
# 2023-08-04 00:00:00+05:00                  785.0          25.5            0.0
# 2023-08-04 01:00:00+05:00                  810.0          25.5            0.0
# 2023-08-04 02:00:00+05:00                  790.0          25.5            0.0
# 2023-08-04 03:00:00+05:00                  845.0          25.5            0.0
# 2023-08-04 04:00:00+05:00                  830.0          25.5            0.0
# ...                                          ...           ...            ...
# 2026-07-30 19:00:00+05:00                  460.0          26.0            0.0
# 2026-07-30 20:00:00+05:00                  425.0          26.2            0.0
# 2026-07-30 21:00:00+05:00                  425.0          26.2            0.0
# 2026-07-30 22:00:00+05:00                  465.0          26.0            0.0
# 2026-07-30 23:00:00+05:00                  420.0          26.3            0.0
#
#                            cloud_cover  wind_direction_10m  wind_gusts_10m  \
# time
# 2023-08-04 00:00:00+05:
#
#                            wind_pollution_dispersion  pressure_change_3hour  \
# time
# 2023-08-04 00:00:00+05:00                    14679.5                    0.2
# 2023-08-04 01:00:00+05:00                    15390.0                   -0.9
# 2023-08-04 02:00:00+05:00                    13983.0                   -1.7
# 2023-08-04 03:00:00+05:00                    14449.5                   -1.4
# 2023-08-04 04:00:00+05:00                    16600.0                   -0.5
# ...                                              ...                    ...
# 2026-07-30 19:00:00+05:00                     4922.0                    0.3
# 2026-07-30 20:00:00+05:00                     4080.0                    0.9
# 2026-07-30 21:00:00+05:00                     3527.5                    1.4
# 2026-07-30 22:00:00+05:00                     4185.0                    1.9
# 2026-07-30 23:00:00+05:00                     3570.0                    1.5
#
#                            Humidity_Level
# time
# 2023-08-04 00:00:00+05:00             1.9
# 2023-08-04 01:00:00+05:00             1.7
# 2023-08-04 02:00:00+05:00             1.5
# 2023-08-04 03:00:00+05:00             1.4
# 2023-08-04 04:00:00+05:00             1.5
# ...                                   ...
# 2026-07-30 19:00:00+05:00             3.7
# 2026-07-30 20:00:00+05:00             3.0
# 2026-07-30 21:00:00+05:00             2.9
# 2026-07-30 22:00:00+05:00             3.2
# 2026-07-30 23:00:00+05:00             3.1
#
# [26208 rows x 49 columns]

# %%
Y
# Out:
# time
# 2023-08-04 00:00:00+05:00    77.0
# 2023-08-04 01:00:00+05:00    77.0
# 2023-08-04 02:00:00+05:00    78.0
# 2023-08-04 03:00:00+05:00    79.0
# 2023-08-04 04:00:00+05:00    79.0
#                              ...
# 2026-07-30 19:00:00+05:00    89.0
# 2026-07-30 20:00:00+05:00    88.0
# 2026-07-30 21:00:00+05:00    88.0
# 2026-07-30 22:00:00+05:00    88.0
# 2026-07-30 23:00:00+05:00    88.0
# Name: Day_2_Future_AQI, Length: 26208, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, shuffle = False)

# %%
len(X_train)
# Out:
# 20966

# %%
len(X_test)
# Out:
# 5242

# %% [markdown]
# # Building XGBoost Model For Day Two

# %%
model = XGBRegressor(n_estimators = 520, 
                     learning_rate = 0.033,
                     max_depth = 3, 
                     random_state = 42, 
                     colsample_bytree = 0.7, 
                     subsample = 0.7,
                     min_child_weight = 5,
                     gamma=0.1,
                     reg_alpha=0.1,
                     reg_lambda=1.5,
                    )

# %%
model.fit(X_train, Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.1, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.033, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=5, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=520,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # Evaluating the Model

# %%
R2_Score = r2_score(Y_test, y_pred)
Mae = mean_absolute_error(Y_test, y_pred)
Mean_Square_Error = mean_squared_error(Y_test, y_pred)
Root_Mean_Square_Error = np.sqrt(Mean_Square_Error)

print("Evaluation Metrics: ")
print(f"R2 Score: {R2_Score}")
print(f"Mean Absolute Error: {Mae}")
print(f"Mean Square Error: {Mean_Square_Error}")
print(f"Root Mean Square Error: {Root_Mean_Square_Error}")
# Out:
# Evaluation Metrics:
# R2 Score: 0.349388412263519
# Mean Absolute Error: 11.754038276948895
# Mean Square Error: 261.56141949635736
# Root Mean Square Error: 16.172860584830296

# %% [markdown]
# # Note:
# - Not much Improvement will come even if I do hyper parameter optimization. I will try other method

# %% [markdown]
# # Now Day Wise

# %%
day2 = pd.read_csv(PROCESSED_DIR / "Day_Two_AQI.csv", index_col="time", parse_dates=True)
day2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1090 entries, 2023-08-04 00:00:00+05:00 to 2026-07-28 00:00:00+05:00
# Data columns (total 49 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   temperature_2m             1090 non-null   float64
#  1   wind_speed_10m             1090 non-null   float64
#  2   relative_humidity_2m       1090 non-null   float64
#  3   surface_pressure           1090 non-null   float64
#  4   boundary_layer_height      909 non-null    float64
#  5   dew_point_2m               1090 non-null   float64
#  6   precipitation              1090 non-null   float64
#  7   cloud_cover                1090 non-null   float64
#  8   wind_direction_10m         1090 non-null   float64
#  9   wind_gusts_10m             1090 non-null   float64
#  10  shortwave_radiation        1090 non-null   float64
#  11  pm10                       1090 non-null   float64
#  12  pm2_5                      1090 non-null   float64
#  13  carbon_monoxide            1090 non-null   float64
#  14  nitrogen_dioxide           1090 non-null   float64
#  15  sulphur_dioxide            1090 non-null   float64
#  16  ozone                      1090 non-null   float64
#  17  dust                       1090 non-null   float64
#  18  aerosol_optical_depth      1090 non-null   float64
#  19  us_aqi                     1090 non-null   float64
#  20  day                        1090 non-null   float64
#  21  month                      1090 non-null   float64
#  22  dayofweek                  1090 non-null   float64
#  23  quarter                    1090 non-null   float64
#  24  previous_hour_aqi          1090 non-null   float64
#  25  previous_day_aqi           1090 non-null   float64
#  26  aqi_change_rate            1090 non-null   float64
#  27  rolled_mean_aqi_6hr        1090 non-null   float64
#  28  rolled_mean_aqi_24hr       1090 non-null   float64
#  29  rolled_mean_aqi_72hr       1090 non-null   float64
#  30  rolled_std_aqi_6hr         1090 non-null   float64
#  31  rolled_std_aqi_24hr        1090 non-null   float64
#  32  rolled_std_aqi_72hr        1090 non-null   float64
#  33  ewm_aqi_24hr               1090 non-null   float64
#  34  ewm_std_24hr               1090 non-null   float64
#  35  f48_temperature_2m         1090 non-null   float64
#  36  f48_wind_speed_10m         1090 non-null   float64
#  37  f48_relative_humidity_2m   1090 non-null   float64
#  38  f48_surface_pressure       1090 non-null   float64
#  39  f48_boundary_layer_height  909 non-null    float64
#  40  f48_dew_point_2m           1090 non-null   float64
#  41  f48_precipitation          1090 non-null   float64
#  42  f48_cloud_cover            1090 non-null   float64
#  43  f48_wind_gusts_10m         1090 non-null   float64
#  44  f48_shortwave_radiation    1090 non-null   float64
#  45  wind_pollution_dispersion  909 non-null    float64
#  46  pressure_change_3hour      1090 non-null   float64
#  47  Humidity_Level             1090 non-null   float64
#  48  Day_2_Future_AQI           1090 non-null   float64
# dtypes: float64(49)
# memory usage: 425.8 KB

# %%
day2.head()
# Out:
#                            temperature_2m  wind_speed_10m  \
# time
# 2023-08-04 00:00:00+05:00       28.441667       20.516667
# 2023-08-05 00:00:00+05:00       28.329167       21.941667
# 2023-08-06 00:00:00+05:00       28.233333       30.679167
# 2023-08-07 00:00:00+05:00       28.041667       33.220833
# 2023-08-08 00:00:00+05:00       27.995833       29.429167
#
#                            relative_humidity_2m  surface_pressure  \
# time
# 2023-08-04 00:00:00+05:00             83.458333       1000.087500
# 2023-08-05 00:00:00+05:00             81.750000       1002.600000
# 2023-08-06 00:00:00+05:00             80.375000       1001.608333
# 2023-08-07 00:00:00+05:00             80.208333        998.991667
# 2023-08-08 00:00:00+05:00             81.666667        999.362500
#
#                            boundary_layer_height  dew_point_2m  precipitation  \
# time
# 2023-08-04 00:00:00+05:00             752.708333     25.291667       0.037500
# 2023-08-05 00:00:00+05:00             818.333333     24.866667       0.037500
# 2023-08-06 00:00:00+05:00             900.416667     24.479167       0.029167
# 2023-08-07 00:00:00+05:00             916.458333     24.266667       0.070833
# 2023-08-08 00:00:00+05:00             805.416667     24.512500       0.091667
#
#                            cloud_cover  wind_direction_10m  wind_gusts_10m  \
# time
# 2023-08-04 00:00:00+05:00    50.083333          245.083333       31.941667
# 2023-08-05 00:00:00+05:00    69.833333          247.750000       33.450000
# 2023-08-06 00:00:00+05:00    81.625000          254.500000       45.562500
# 2023-08-07 00:00:00+05:00    75.000000          250.250000       49.770833
# 2023-08-08 00:00:00+05:00    68.541667          245.916667       44.275000
#
#                            ...  f48_boundary_layer_height  f48_dew_point_2m  \
# time                       ...
# 2023-08-04 00:00:00+05:00  ...                 900.416667         24.479167
# 2023-08-05 00:00:00+05:00  ...                 916.458333         24.266667
# 2023-08-06 00:00:00+05:00  ...                 805.416667         24.512500
# 2023-08-07 00:00:00+05:00  ...                 798.750000         24.487500
# 2023-08-08 00:00:00+05:00  ...                 776.041667         24.483333
#
#                            f48_precipitation  f48_cloud_cover  \
# time
# 2023-08-04 00:00:00+05:00           0.029167        81.625000
# 2023-08-05 00:00:00+05:00           0.070833        75.000000
# 2023-08-06 00:00:00+05:00           0.091667        68.541667
# 2023-08-07 00:00:00+05:00           0.033333        72.916667
# 2023-08-08 00:00:00+05:00           0.066667        74.833333
#
#                            f48_wind_gusts_10m  f48_shortwave_radiation  \
# time
# 2023-08-04 00:00:00+05:00           45.562500               175.958333
# 2023-08-05 00:00:00+05:00           49.770833               171.375000
# 2023-08-06 00:00:00+05:00           44.275000               172.000000
# 2023-08-07 00:00:00+05:00           43.120833               220.875000
# 2023-08-08 00:00:00+05:00           41.720833               195.583333
#
#                            wind_pollution_dispersion  pressure_change_3hour  \
# time
# 2023-08-04 00:00:00+05:00               15605.187500               0.225000
# 2023-08-05 00:00:00+05:00               18252.291667               0.266667
# 2023-08-06 00:00:00+05:00               27933.375000              -0.387500
# 2023-08-07 00:00:00+05:00               30741.333333              -0.200000
# 2023-08-08 00:00:00+05:00               23936.687500               0.304167
#
#                            Humidity_Level  Day_2_Future_AQI
# time
# 2023-08-04 00:00:00+05:00        3.150000         78.833333
# 2023-08-05 00:00:00+05:00        3.462500         78.875000
# 2023-08-06 00:00:00+05:00        3.754167         78.791667
# 2023-08-07 00:00:00+05:00        3.775000         73.416667
# 2023-08-08 00:00:00+05:00        3.483333         68.791667
#
# [5 rows x 49 columns]

# %%
day2.columns
# Out:
# Index(['temperature_2m', 'wind_speed_10m', 'relative_humidity_2m',
#        'surface_pressure', 'boundary_layer_height', 'dew_point_2m',
#        'precipitation', 'cloud_cover', 'wind_direction_10m', 'wind_gusts_10m',
#        'shortwave_radiation', 'pm10', 'pm2_5', 'carbon_monoxide',
#        'nitrogen_dioxide', 'sulphur_dioxide', 'ozone', 'dust',
#        'aerosol_optical_depth', 'us_aqi', 'day', 'month', 'dayofweek',
#        'quarter', 'previous_hour_aqi', 'previous_day_aqi', 'aqi_change_rate',
#        'rolled_mean_aqi_6hr', 'rolled_mean_aqi_24hr', 'rolled_mean_aqi_72hr',
#        'rolled_std_aqi_6hr', 'rolled_std_aqi_24hr', 'rolled_std_aqi_72hr',
#        'ewm_aqi_24hr', 'ewm_std_24hr', 'f48_temperature_2m',
#        'f48_wind_speed_10m', 'f48_relative_humidity_2m',
#        'f48_surface_pressure', 'f48_boundary_layer_height', 'f48_dew_point_2m',
#        'f48_precipitation', 'f48_cloud_cover', 'f48_wind_gusts_10m',
#        'f48_shortwave_radiation', 'wind_pollution_dispersion',
#        'pressure_change_3hour', 'Humidity_Level', 'Day_2_Future_AQI'],
#       dtype='object')

# %%
X1 = day2.drop(columns = ['Day_2_Future_AQI'])
Y1 = day2['Day_2_Future_AQI']

# %%
X1
# Out:
#                            temperature_2m  wind_speed_10m  \
# time
# 2023-08-04 00:00:00+05:00       28.441667       20.516667
# 2023-08-05 00:00:00+05:00       28.329167       21.941667
# 2023-08-06 00:00:00+05:00       28.233333       30.679167
# 2023-08-07 00:00:00+05:00       28.041667       33.220833
# 2023-08-08 00:00:00+05:00       27.995833       29.429167
# ...                                   ...             ...
# 2026-07-24 00:00:00+05:00       30.233333        9.304167
# 2026-07-25 00:00:00+05:00       29.541667       10.587500
# 2026-07-26 00:00:00+05:00       29.687500       10.466667
# 2026-07-27 00:00:00+05:00       29.829167       14.262500
# 2026-07-28 00:00:00+05:00       29.450000       15.620833
#
#                            relative_humidity_2m  surface_pressure  \
# time
# 2023-08-04 00:00:00+05:00             83.458333       1000.087500
# 2023-08-05 00:00:00+05:00             81.750000       1002.600000
# 2023-08-06 00:00:00+05:00             80.375000       1001.608333
# 2023-08-07 00:00:00+05:00             80.208333        998.991667
# 2023-08-08 00:00:00+05:00             81.666667        999.362500
# ...                                         ...               ...
# 2026-07-24 00:00:00+05:00             76.625000        997.970833
# 2026-07-25 00:00:00+05:00             76.500000        999.633333
# 2026-07-26 00:00:00+05:00             73.000000       1000.854167
# 2026-07-27 00:00:00+05:00             73.125000        999.862500
# 2026-07-28 00:00:00+05:00             75.458333        997.587500
#
#                            boundary_layer_height  dew_point_2m  precipitation  \
# time
# 2023-08-04 00:00:00+05:00             752.708333     25.291667       0.037500
# 2023-08-05 00:00:00+05:00             818.333333     24.866667       0.037500
# 2023-08-06 00:00:00+05:00             900.416667     24.479167       0.029167
# 2023-08-07 00:00:00+05:00             916.458333     24.266667       0.070833
# 2023-08-08 00:00:00+05:00             805.416667     24.512500       0.091667
# ...                                          ...           ...            ...
# 2026-07-24 00:00:00+05:00             503.958333     25.545833       0.000000
# 2026-07-25 00:00:00+05:00             583.750000     24.916667       0.000000
# 2026-07-26 00:00:00+05:00             598.958333     24.254167       0.000000
# 2026-07-27 00:00:00+05:00             770.208333     24.387500       0.004167
# 2026-07-28 00:00:00+05:00             736.041667     24.587500       0.012500
#
#                            cloud_cover  wind_direction_10m  wind_gusts_10m  \
# time
# 2023-08-04 00:00:00+05:00    50.083333          245.083333       31.941667
# 2023-08-05 00:00:00+05:00    69.833333          247.750000       33.450000
# 2023-08-06 00:00:00+05:00    81.625000          254.500000       45.562500
# 2023-08-07 00:00:00+05:00    75.000000          250.250000       49.770833
# 2023-08-08 00:00:00+05:00    68.541667          245.916667       44.275000
# ...                                ...                 ...             ...
# 2026-07-24 00:00:00+05:00    77.375000          233.250000       26.816667
# 2026-07-25 00:00:00+05:00    98.833333          244.375000       28.675000
# 2026-07-26 00:00:00+05:00    78.416667          262.625000       27.916667
# 2026-07-27 00:00:00+05:00    67.166667          256.791667       35.854167
# 2026-07-28 00:00:00+05:00    50.750000          244.333333       39.495833
#
#                            ...  f48_surface_pressure  \
# time                       ...
# 2023-08-04 00:00:00+05:00  
#
#                            wind_pollution_dispersion  pressure_change_3hour  \
# time
# 2023-08-04 00:00:00+05:00               15605.187500               0.225000
# 2023-08-05 00:00:00+05:00               18252.291667               0.266667
# 2023-08-06 00:00:00+05:00               27933.375000              -0.387500
# 2023-08-07 00:00:00+05:00               30741.333333              -0.200000
# 2023-08-08 00:00:00+05:00               23936.687500               0.304167
# ...                                              ...                    ...
# 2026-07-24 00:00:00+05:00                4833.645833               0.104167
# 2026-07-25 00:00:00+05:00                6285.291667               0.262500
# 2026-07-26 00:00:00+05:00                6418.562500               0.050000
# 2026-07-27 00:00:00+05:00               11240.770833              -0.254167
# 2026-07-28 00:00:00+05:00               11677.250000              -0.137500
#
#                            Humidity_Level
# time
# 2023-08-04 00:00:00+05:00        3.150000
# 2023-08-05 00:00:00+05:00        3.462500
# 2023-08-06 00:00:00+05:00        3.754167
# 2023-08-07 00:00:00+05:00        3.775000
# 2023-08-08 00:00:00+05:00        3.483333
# ...                                   ...
# 2026-07-24 00:00:00+05:00        4.687500
# 2026-07-25 00:00:00+05:00        4.625000
# 2026-07-26 00:00:00+05:00        5.433333
# 2026-07-27 00:00:00+05:00        5.441667
# 2026-07-28 00:00:00+05:00        4.862500
#
# [1090 rows x 48 columns]

# %%
Y1
# Out:
# time
# 2023-08-04 00:00:00+05:00    78.833333
# 2023-08-05 00:00:00+05:00    78.875000
# 2023-08-06 00:00:00+05:00    78.791667
# 2023-08-07 00:00:00+05:00    73.416667
# 2023-08-08 00:00:00+05:00    68.791667
#                                ...
# 2026-07-24 00:00:00+05:00    82.041667
# 2026-07-25 00:00:00+05:00    83.250000
# 2026-07-26 00:00:00+05:00    78.708333
# 2026-07-27 00:00:00+05:00    79.125000
# 2026-07-28 00:00:00+05:00    80.416667
# Name: Day_2_Future_AQI, Length: 1090, dtype: float64

# %%
X_train1, X_test1, Y_train1, Y_test1 = train_test_split(X1, Y1, test_size=0.2, shuffle = False)

# %%
len(X_train1)
# Out:
# 872

# %%
len(X_test1)
# Out:
# 218

# %% [markdown]
# # Building XGBoost Model For Day Two

# %%
model1 = XGBRegressor(n_estimators = 520, 
                     learning_rate = 0.033,
                     max_depth = 3, 
                     random_state = 42, 
                     colsample_bytree = 0.7, 
                     subsample = 0.7,
                     min_child_weight = 5,
                     gamma=0.1,
                     reg_alpha=0.1,
                     reg_lambda=1.5,
                    ) 

model1.fit(X_train1, Y_train1)
y_pred1 = model1.predict(X_test1)

# %% [markdown]
# # Evaluating the Model

# %%
R2_Score1 = r2_score(Y_test1, y_pred1)
Mae1 = mean_absolute_error(Y_test1, y_pred1)
Mean_Square_Error1 = mean_squared_error(Y_test1, y_pred1)
Root_Mean_Square_Error1 = np.sqrt(Mean_Square_Error1)

print("Evaluation Metrics: ")
print(f"R2 Score: {R2_Score1}")
print(f"Mean Absolute Error: {Mae1}")
print(f"Mean Square Error: {Mean_Square_Error1}")
print(f"Root Mean Square Error: {Root_Mean_Square_Error1}")
# Out:
# Evaluation Metrics:
# R2 Score: 0.4991361525867194
# Mean Absolute Error: 9.592959156094706
# Mean Square Error: 180.0379272886
# Root Mean Square Error: 13.417821257141563

# %%
randomForest = RandomForestClassifier(n_estimators = 520, 
                     learning_rate = 0.033,
                     max_depth = 3, 
                     random_state = 42, )
randomForest.fit(X_train1, Y_train1)
