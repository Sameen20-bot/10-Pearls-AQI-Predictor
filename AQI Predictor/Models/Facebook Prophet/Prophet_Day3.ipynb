# %%
import pandas as pd
import numpy as np

from prophet import Prophet

from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error

import plotly.graph_objs as go
import plotly.offline as py

from pathlib import Path
import os
from dotenv import load_dotenv
import hopsworks

# %%
CWD = Path.cwd()
PROJECT_ROOT = CWD.parent.parent
PROCESSED_DIR = PROJECT_ROOT / "Data" / "Processed"

# %%
load_dotenv(PROJECT_ROOT / ".env")

key = os.getenv("HOPSWORK_KEY")

# %%
project = hopsworks.login(
    project='aqi_karachi_samu_2026',
    host="eu-west.cloud.hopsworks.ai",
    port=443,
    api_key_value=key,
)

fs = project.get_feature_store()
print(f"Connected to {project.name}")
# Out:
# 2026-08-23 22:51:54,652 INFO: Initializing external client
# 2026-08-23 22:51:54,653 INFO: Base URL: https://eu-west.cloud.hopsworks.ai:443
# 2026-08-23 22:51:58,895 INFO: Python Engine initialized.
# Logged in to project, explore it here https://eu-west.cloud.hopsworks.ai:443/p/41193
# Connected to aqi_karachi_samu_2026

# %%
target = "day_3_future_aqi"
day_3_fv = fs.get_feature_view(name="view_aqi_day3", version=1)

# %%
x, y = day_3_fv.training_data()
# Out:
# Reading data from Hopsworks, using Hopsworks Feature Query Service.
# 2026-08-23 22:52:11,834 INFO: Computing insert statistics
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (2.44s)
# VersionWarning: Incremented version to `5`.

# %%
day3 = x.copy()
day3[target] = y[target]

# %%
day3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1088 entries, 0 to 1087
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   time                         1088 non-null   object
#  1   temperature_2m               1088 non-null   float64
#  2   wind_speed_10m               1088 non-null   float64
#  3   relative_humidity_2m         1088 non-null   float64
#  4   surface_pressure             1088 non-null   float64
#  5   boundary_layer_height        907 non-null    float64
#  6   dew_point_2m                 1088 non-null   float64
#  7   precipitation                1088 non-null   float64
#  8   cloud_cover                  1088 non-null   float64
#  9   wind_direction_10m           1088 non-null   float64
#  10  wind_gusts_10m               1088 non-null   float64
#  11  shortwave_radiation          1088 non-null   float64
#  12  pm10                         1088 non-null   float64
#  13  pm2_5                        1088 non-null   float64
#  14  carbon_monoxide              1088 non-null   float64
#  15  nitrogen_dioxide             1088 non-null   float64
#  16  sulphur_dioxide              1088 non-null   float64
#  17  ozone                        1088 non-null   float64
#  18  dust                         1088 non-null   float64
#  19  aerosol_optical_depth        1088 non-null   float64
#  20  us_aqi                       1088 non-null   float64
#  21  month                        1088 non-null   float64
#  22  dayofweek                    1088 non-null   float64
#  23  previous_day_aqi             1088 non-null   float64
#  24  rolled_mean_aqi_24hr         1088 non-null   float64
#  25  rolled_mean_aqi_72hr         1088 non-null   float64
#  26  rolled_std_aqi_24hr          1088 non-null   float64
#  27  rolled_std_aqi_72hr          1088 non-null   float64
#  28  ewm_aqi_24hr                 1088 non-null   float64
#  29  ewm_std_24hr                 1088 non-null   float64
#  30  f72_temperature_2m           1088 non-null   float64
#  31  f72_wind_speed_10m           1088 non-null   float64
#  32  f72_relative_humidity_2m     1088 non-null   float64
#  33  f72_surface_pressure         1088 non-null   float64
#  34  f72_boundary_layer_height    907 non-null    float64
#  35  f72_dew_point_2m             1088 non-null   float64
#  36  f72_precipitation            1088 non-null   float64
#  37  f72_cloud_cover              1088 non-null   float64
#  38  f72_wind_gusts_10m           1088 non-null   float64
#  39  f72_shortwave_radiation      1088 non-null   float64
#  40  wind_pollution_dispersion    907 non-null    float64
#  41  pressure_change_3hour        1088 non-null   float64
#  42  humidity_level               1088 non-null   float64
#  43  cyclic_day_sin               1088 non-null   float64
#  44  cyclic_day_cos               1088 non-null   float64
#  45  cyclic_week_sin              1088 non-null   float64
#  46  cyclic_week_cos              1088 non-null   float64
#  47  delta_temperature_2m         1088 non-null   float64
#  48  delta_wind_speed_10m         1088 non-null   float64
#  49  delta_surface_pressure       1088 non-null   float64
#  50  delta_relative_humidity_2m   1088 non-null   float64
#  51  delta_boundary_layer_height  904 non-null    float64
#  52  day_3_future_aqi             1088 non-null   float64
# dtypes: float64(52), object(1)
# memory usage: 450.6+ KB

# %%
day3.time = pd.to_datetime(day3.time)

# %%
day3 = day3.sort_values("time").reset_index(drop=True)

# %%
day3 = day3.drop(columns = ["boundary_layer_height", "f72_boundary_layer_height", "wind_pollution_dispersion", "delta_boundary_layer_height"])

# %%
day3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1088 entries, 0 to 1087
# Data columns (total 49 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   time                        1088 non-null   datetime64[ns, UTC]
#  1   temperature_2m              1088 non-null   float64
#  2   wind_speed_10m              1088 non-null   float64
#  3   relative_humidity_2m        1088 non-null   float64
#  4   surface_pressure            1088 non-null   float64
#  5   dew_point_2m                1088 non-null   float64
#  6   precipitation               1088 non-null   float64
#  7   cloud_cover                 1088 non-null   float64
#  8   wind_direction_10m          1088 non-null   float64
#  9   wind_gusts_10m              1088 non-null   float64
#  10  shortwave_radiation         1088 non-null   float64
#  11  pm10                        1088 non-null   float64
#  12  pm2_5                       1088 non-null   float64
#  13  carbon_monoxide             1088 non-null   float64
#  14  nitrogen_dioxide            1088 non-null   float64
#  15  sulphur_dioxide             1088 non-null   float64
#  16  ozone                       1088 non-null   float64
#  17  dust                        1088 non-null   float64
#  18  aerosol_optical_depth       1088 non-null   float64
#  19  us_aqi                      1088 non-null   float64
#  20  month                       1088 non-null   float64
#  21  dayofweek                   1088 non-null   float64
#  22  previous_day_aqi            1088 non-null   float64
#  23  rolled_mean_aqi_24hr        1088 non-null   float64
#  24  rolled_mean_aqi_72hr        1088 non-null   float64
#  25  rolled_std_aqi_24hr         1088 non-null   float64
#  26  rolled_std_aqi_72hr         1088 non-null   float64
#  27  ewm_aqi_24hr                1088 non-null   float64
#  28  ewm_std_24hr                1088 non-null   float64
#  29  f72_temperature_2m          1088 non-null   float64
#  30  f72_wind_speed_10m          1088 non-null   float64
#  31  f72_relative_humidity_2m    1088 non-null   float64
#  32  f72_surface_pressure        1088 non-null   float64
#  33  f72_dew_point_2m            1088 non-null   float64
#  34  f72_precipitation           1088 non-null   float64
#  35  f72_cloud_cover             1088 non-null   float64
#  36  f72_wind_gusts_10m          1088 non-null   float64
#  37  f72_shortwave_radiation     1088 non-null   float64
#  38  pressure_change_3hour       1088 non-null   float64
#  39  humidity_level              1088 non-null   float64
#  40  cyclic_day_sin              1088 non-null   float64
#  41  cyclic_day_cos              1088 non-null   float64
#  42  cyclic_week_sin             1088 non-null   float64
#  43  cyclic_week_cos             1088 non-null   float64
#  44  delta_temperature_2m        1088 non-null   float64
#  45  delta_wind_speed_10m        1088 non-null   float64
#  46  delta_surface_pressure      1088 non-null   float64
#  47  delta_relative_humidity_2m  1088 non-null   float64
#  48  day_3_future_aqi            1088 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(48)
# memory usage: 416.6 KB

# %% [markdown]
# # Train and Test Split

# %%
Train = day3.iloc[:873,:]

# %%
Test = day3.iloc[873:,:]

# %%
Train.shape
# Out:
# (873, 49)

# %%
Test.shape
# Out:
# (215, 49)

# %%
Train.head()
# Out:
#                        time  temperature_2m  wind_speed_10m  \
# 0 2023-08-04 00:00:00+00:00       28.441667       20.516667
# 1 2023-08-05 00:00:00+00:00       28.329167       21.941667
# 2 2023-08-06 00:00:00+00:00       28.233333       30.679167
# 3 2023-08-07 00:00:00+00:00       28.041667       33.220833
# 4 2023-08-08 00:00:00+00:00       27.995833       29.429167
#
#    relative_humidity_2m  surface_pressure  dew_point_2m  precipitation  \
# 0             83.458333       1000.087500     25.291667       0.037500
# 1             81.750000       1002.600000     24.866667       0.037500
# 2             80.375000       1001.608333     24.479167       0.029167
# 3             80.208333        998.991667     24.266667       0.070833
# 4             81.666667        999.362500     24.512500       0.091667
#
#    cloud_cover  wind_direction_10m  wind_gusts_10m  ...  humidity_level  \
# 0    50.083333          245.083333       31.941667  ...        3.150000
# 1    69.833333          247.750000       33.450000  ...        3.462500
# 2    81.625000          254.500000       45.562500  ...        3.754167
# 3    75.000000          250.250000       49.770833  ...        3.775000
# 4    68.541667          245.916667       44.275000  ...        3.483333
#
#    cyclic_day_sin  cyclic_day_cos  cyclic_week_sin  cyclic_week_cos  \
# 0       -0.545240       -0.838280        -0.433884        -0.900969
# 1       -0.559589       -0.828770        -0.974928        -0.222521
# 2       -0.573772       -0.819015        -0.781831         0.623490
# 3       -0.587785       -0.809017         0.000000         1.000000
# 4       -0.601624       -0.798779         0.781831         0.623490
#
#    delta_temperature_2m  delta_wind_speed_10m  delta_surface_pressure  \
# 0             -0.400000             12.704167               -1.095833
# 1             -0.333333              7.487500               -3.237500
# 2             -0.262500             -2.241667                0.979167
# 3             -0.212500             -5.650000                4.616667
# 4             -0.275000             -3.066667                4.620833
#
#    delta_relative_humidity_2m  day_3_future_aqi
# 0                   -3.250000         78.875000
# 1                   -0.083333         78.791667
# 2                    1.250000         73.416667
# 3                    2.250000         68.791667
# 4                    0.625000         69.916667
#
# [5 rows x 49 columns]

# %%
Test.head()
# Out:
#                          time  temperature_2m  wind_speed_10m  \
# 873 2025-12-24 00:00:00+00:00       20.666667        7.579167
# 874 2025-12-25 00:00:00+00:00       19.608333        6.100000
# 875 2025-12-26 00:00:00+00:00       19.729167        5.962500
# 876 2025-12-27 00:00:00+00:00       20.204167        7.041667
# 877 2025-12-28 00:00:00+00:00       20.337500        6.658333
#
#      relative_humidity_2m  surface_pressure  dew_point_2m  precipitation  \
# 873             46.458333       1015.737500      7.979167            0.0
# 874             56.666667       1014.941667     10.575000            0.0
# 875             67.250000       1014.783333     12.845833            0.0
# 876             49.208333       1015.150000      8.495833            0.0
# 877             42.541667       1015.270833      6.675000            0.0
#
#      cloud_cover  wind_direction_10m  wind_gusts_10m  ...  humidity_level  \
# 873    10.666667          139.666667       18.550000  ...       12.687500
# 874    81.750000          187.833333       15.454167  ...        9.033333
# 875    20.458333          172.958333       14.829167  ...        6.883333
# 876     5.333333          109.583333       17.029167  ...       11.708333
# 877    23.125000          130.250000       16.187500  ...       13.662500
#
#      cyclic_day_sin  cyclic_day_cos  cyclic_week_sin  cyclic_week_cos  \
# 873       -0.120208        0.992749         0.974928        -0.222521
# 874       -0.103102        0.994671         0.433884        -0.900969
# 875       -0.085965        0.996298        -0.433884        -0.900969
# 876       -0.068802        0.997630        -0.974928        -0.222521
# 877       -0.051620        0.998667        -0.781831         0.623490
#
#      delta_temperature_2m  delta_wind_speed_10m  delta_surface_pressure  \
# 873             -0.462500             -0.537500               -0.587500
# 874              0.729167              0.558333                0.329167
# 875              0.529167              0.829167                0.020833
# 876              0.266667              0.216667               -2.487500
# 877              0.870833              2.954167               -5.575000
#
#      delta_relative_humidity_2m  day_3_future_aqi
# 873                    2.750000        122.375000
# 874                  -14.125000        121.666667
# 875                  -19.333333        128.458333
# 876                   18.791667        127.000000
# 877                   21.875000         96.750000
#
# [5 rows x 49 columns]

# %% [markdown]
# # Renaming the columns to ds and y

# %%
Train = Train.rename(columns = {'day_3_future_aqi':'y', 'time':'ds'})
Test = Test.rename(columns = {'day_3_future_aqi':'y', 'time':'ds'})

# %%
Train["ds"] = Train["ds"].dt.tz_localize(None)
Test["ds"]  = Test["ds"].dt.tz_localize(None)

# %% [markdown]
# # Saving The Copy

# %%
Train['y_orig'] = Train['y']
Test['y_orig'] = Test['y']

# %% [markdown]
# # Log Transformation

# %%
Train['y'] = np.log(Train['y'])
Test['y'] = np.log(Test['y'])

# %% [markdown]
# # Model Build

# %%
model = Prophet()
model.add_regressor("rolled_mean_aqi_24hr")
model.add_regressor("f72_wind_speed_10m")
model.add_regressor("f72_dew_point_2m")
model.fit(Train)
# Out:
# 2026-08-23 22:52:15,018 INFO: Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 2026-08-23 22:52:15,065 INFO: Chain [1] start processing
# 2026-08-23 22:52:15,152 INFO: Chain [1] done processing

# %% [markdown]
# # For Plotting Training and Testing Data

# %%
future_Data_Plot = pd.concat([Train, Test], ignore_index = True)
future_Data_Plot_Predict = model.predict(future_Data_Plot)
model.plot(future_Data_Plot_Predict);

# %%
model.plot_components(future_Data_Plot_Predict);

# %% [markdown]
# # Now Check the Plot with Without Regressor

# %%
model_simple = Prophet(yearly_seasonality=True)
model_simple.fit(Train)
# Out:
# 2026-08-23 22:52:16,633 INFO: Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 2026-08-23 22:52:16,676 INFO: Chain [1] start processing
# 2026-08-23 22:52:16,731 INFO: Chain [1] done processing

# %%
future_Data_Plot_Predict1 = model_simple.predict(future_Data_Plot)
model_simple.plot(future_Data_Plot_Predict1);

# %%
model_simple.plot_components(future_Data_Plot_Predict1);

# %% [markdown]
# # Inverse Transformation

# %%
future_Data_Plot_Backup = future_Data_Plot_Predict.copy()

# %%
future_Data_Plot_Backup["yhat"] = np.exp(future_Data_Plot_Backup["yhat"])
future_Data_Plot_Backup["yhat_lower"] = np.exp(future_Data_Plot_Backup["yhat_lower"])
future_Data_Plot_Backup["yhat_upper"] = np.exp(future_Data_Plot_Backup["yhat_upper"])

# %%
future_Data_Plot_Backup.head()
# Out:
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 2023-08-04  4.505315   53.793513   81.876898     4.505315     4.505315
# 1 2023-08-05  4.505426   56.194544   85.770453     4.505426     4.505426
# 2 2023-08-06  4.505536   55.737688   84.619699     4.505536     4.505536
# 3 2023-08-07  4.505647   56.386223   85.979963     4.505647     4.505647
# 4 2023-08-08  4.505758   55.776763   85.167042     4.505758     4.505758
#
#    additive_terms  additive_terms_lower  additive_terms_upper  \
# 0       -0.305678             -0.305678             -0.305678
# 1       -0.261952             -0.261952             -0.261952
# 2       -0.273008             -0.273008             -0.273008
# 3       -0.271259             -0.271259             -0.271259
# 4       -0.263303             -0.263303             -0.263303
#
#    extra_regressors_additive  ...    weekly  weekly_lower  weekly_upper  \
# 0                  -0.302073  ...  0.009061      0.009061      0.009061
# 1                  -0.248831  ...  0.008055      0.008055      0.008055
# 2                  -0.240857  ... -0.002995     -0.002995     -0.002995
# 3                  -0.230053  ... -0.004632     -0.004632     -0.004632
# 4                  -0.211008  ... -0.008887     -0.008887     -0.008887
#
#      yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0 -0.012666     -0.012666     -0.012666                   0.0
# 1 -0.021177     -0.021177     -0.021177                   0.0
# 2 -0.029156     -0.029156     -0.029156                   0.0
# 3 -0.036573     -0.036573     -0.036573                   0.0
# 4 -0.043408     -0.043408     -0.043408                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 0                         0.0                         0.0  66.662109
# 1                         0.0                         0.0  69.649345
# 2                         0.0                         0.0  68.891191
# 3                         0.0                         0.0  69.019456
# 4                         0.0                         0.0  69.578457
#
# [5 rows x 31 columns]

# %%
model.plot(future_Data_Plot_Backup);

# %% [markdown]
# # Evaluation

# %%
forecast_test = model.predict(Test)
y_pred = np.exp(forecast_test["yhat"])
y_true = Test["y_orig"].values

print(f"R2 Score: {r2_score(y_true, y_pred)}")
print(f"Mean Absolute Error: {mean_absolute_error(y_true, y_pred)}")
print(f"Root Mean Square Error: {np.sqrt(mean_squared_error(y_true, y_pred))}")
print(f"Mean Square Error: {mean_squared_error(y_true, y_pred)}")
# Out:
# R2 Score: 0.2605910928009153
# Mean Absolute Error: 12.649127696752517
# Root Mean Absolute Error: 3.556561217911554
# Mean Square Error: 263.1586582895419

# %% [markdown]
# # Note: Prophet not working well on the data, tuning will not be effective too.
